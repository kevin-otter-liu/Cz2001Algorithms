# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# to plot no. of nearest hospitals chosen to be displayed against time taken by BFS search

# %%
data_dict = {381:13141449400, 186:7862657901, 376:13223285400, 181:7333477500, 371:13090609499, 176:7076784400, 366:13130650900, 171:7307632500, 361:12478125300, 166:6761905200, 356:12192069199, 161:6665707000, 351:11994854301, 156:7107389901, 346:11653377400, 151:6763778700, 341:11794310000, 146:6730433200, 336:11292136100, 141:6386308900, 331:10798612599, 136:6158937800, 326:10577240499, 131:5531425601, 321:10916391100, 126:4938726800, 316:10963695499, 121:4661404399, 311:12075691501, 116:4597830800, 306:10203642299, 111:4218719501, 301:9648035400, 106:4049788700, 296:9529425799, 101:3995945301, 291:10398090100, 96:3870851900, 286:9335175599, 91:3751131701, 281:10027217101, 86:3957548001, 276:9416093300, 81:4169447699, 271:9233437700, 76:3801872000, 266:9466515400, 71:3713443000, 261:9202254700, 66:3639065200, 256:10201888800, 61:3414775200, 251:9141335500, 56:3276711600, 246:9464549000, 51:3077734400, 241:9186114300, 46:3304250299, 236:9080684400, 41:3281283900, 231:8756290199, 36:3019490700, 226:8621929500, 31:2766700200, 221:8626330799, 26:2639704701, 216:8317177600, 21:2455269800, 211:8132811600, 16:2338226600, 206:8508890700, 396:14821635099, 11:2126140400, 201:7795809199, 391:13783416999, 6:1944199800, 196:7674192800, 386:13424280400, 1:2136517001, 191:7372400300}

# %%
x=[]
y=[]
for keys,value in data_dict.items():
    x.append(keys)
    y.append(value)

# %%
#increasing number of neareest selected hospitals
x = np.asarray(x)
y = np.asarray(y)
m,c = np.polyfit(x,y,1)
plt.plot(x,m*x+c)
plt.plot(x,y,'o')
plt.xlabel("k")
plt.ylabel("Time taken")
plt.title("Time taken for BFS against k")
plt.show()

# %%
hospital_against_time = {850:1783322301, 1800:1839524001, 1700:1793616200, 750:1788680700, 1600:1802689301, 650:1807489500, 550:1781758900, 1500:1845768800, 450:1815358999, 1400:1746167800, 350:1879486300, 1300:1794116899, 250:1848448100, 1200:1856200300, 1100:1785057000, 1950:1820102001, 1000:1790904699, 900:1825252700, 1850:1805885800, 800:1779182900, 1750:1867439300, 1650:1855613299, 700:1785773900, 600:1813050400, 1550:1758847300, 500:1818890700, 1450:1818056200, 400:1846758700, 1350:1792027601, 300:1854523200, 1250:1787093899, 200:2292510499, 1150:1797459400, 2000:1805808000, 1050:1728905500, 950:1744820601, 1900:1802292599}

# %%
x_hospital_inputted=[]
y_time=[]
for keys,value in hospital_against_time.items():
    x_hospital_inputted.append(keys)
    y_time.append(value)

# %%
#increasing number of hospitals
x = np.asarray(x_hospital_inputted)
y=np.asarray(y_time)
plt.plot(x,y,'o')
plt.xlabel("h - no. of hospitals")
plt.ylabel("Time taken")
plt.title("Time taken for BFS against h")
plt.show()
